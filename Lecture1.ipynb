# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Nonlinear Dynamics
# # 1.2 Maps and difference equation Test

# %% [markdown]
# # Exercise 2

# %%
def logistic(x,r):
    return r*x*(1-x)

# %%
x_new = 0.2; r = 2.6;
n = 10;

# %%
for ii in range(n):
    x_new = logistic(x_new, r)
    print(x_new)
# Out:
# 0.41600000000000004
# 0.6316544000000001
# 0.604934509297664
# 0.621370746771992
# 0.6116997687528234
# 0.617560220317471
# 0.6140669459571599
# 0.6161707027840165
# 0.614911356318136
# 0.6156679884917287

# %% [markdown]
# # 1.4 Homework

# %% [markdown]
# #  Q1

# %%
R = [2,3.4,3.72];
n = 500000;

# %%
def PlotLogisticMap(R,n):
    rlength= len(R);
    results1 = np.zeros((rlength,n));
    results2 = np.zeros((rlength,n));
    
    # calculate the logistic map
    for r in range(rlength):
        # set initial values
        x1_new = 0.2; x2_new = 0.200001;
        results1[r,0] = x1_new;
        results2[r,0] = x2_new;
        for ii in range(1, n):
            x1_new = logistic(x1_new, R[r])
            x2_new = logistic(x2_new, R[r])
            results1[r,ii] = x1_new; results2[r,ii] = x2_new; 
    
    # plot the results of abs difference between two lines
    for r in range(rlength):
        plt.figure(r);
        plt.plot(np.abs(results1[r,:]-results2[r,:]));
        
    plt.show();
    return results1,results2

# %%
n = 5000;
[result1, result2] = PlotLogisticMap(R,n);

# %%
np.mean(abs(result1[2,:]-result2[2,:]))
# Out:
# 0.24363230870799679

# %%
n=500000;
[result1, result2] = PlotLogisticMap(R,n);
np.mean(abs(result1[2,:]-result2[2,:]))
# Out:
# 0.24406660586145995
