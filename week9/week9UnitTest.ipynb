# %%
from IPython.display import Image
# Image("content_capacity-dimension-set.jpg")

# %% [markdown]
# # Q1. What's the difference between capacity dimension and correlation dimension?

# %% [markdown]
# ## A. Capacity dimension measures the number of boxes needed to cover the points in a set, whereas correlation dimension measures the clustering of those points.
# ## B. Calculating correlation dimension is much slower than calculating capacity dimension.
# ## C. Both of them measure exactly the same thing; the only difference is the algorithm used to calculate them.
# ## D. Sauer et al. proposed the correlation dimension, whereas Grassberger and Procaccia proposed the box-counting dimension.
# ## Answer: A. Capacity dimension measures the number of boxes needed to cover the points in a set, whereas correlation dimension measures the clustering of those points.

# %% [markdown]
# # Q2. Consider the following image of a step in the calculation of the capacity dimension of the Julia set that was discussed in this unit:

# %%
 Image("content_screen_sh.png")

# %% [markdown]
# # Q2. What is N($\epsilon$) in this image?

# %% [markdown]
# # 12
# ## 0.125^2
# ## 0.125
# ## 32
# ## Answer: 32

# %% [markdown]
# # Q3. Does this curve have a scaling region?

# %%
Image('content_wrongscaleregion.jpg')

# %% [markdown]
# # Answer: Yes

# %% [markdown]
# # Q4. How could one compute the capacity dimension of a set from the curve in question 3?
# ## The y intercept of a line fitted to the scaling region (if one exists).
# ## The slope of a line fitted to the scaling region (if one exists).
# ## The lowest value of \log N(\epsilon) where the curve flattens out
# ## The lowest value of \log N(\epsilon) where the curve becomes a line
# ## None of the above - something's really wrong with this curve!
# ## Answer: None of the above - something's really wrong with this curve!

# %% [markdown]
# # Q5. When calculating capacity dimension, why does the curve on a plot of $\log(N(\epsilon))$ flatten out for high values of $\log ({1}/{\epsilon})$?

# %% [markdown]
# ## Because one $\epsilon-ball$ is covering the whole set.
# ## Because each -ball is covering a single point.
# ## Because there's a power-law relationship between these two quantities.
# ## Answer: # Because each -ball is covering a single point.

# %% [markdown]
# # Q6. Download amplitude.dat . Use your delay-coordinate embedding code from the unit homework to embed this time series using m=2 and $\tau=8$. Use your capacity dimension calculator from the unit 9 homework to calculate N(0.5) for this embeded trajectory.  What do you get?

# %% [markdown]
# # 0.5
# ## 4516
# ## 2089
# ## 664
# ## 944
# ## Answer:

# %% [markdown]
# # Q7. The correlation sum C$(\epsilon)$ is proporional to $\epsilon^{d_{correlation}}$.

# %% [markdown]
# # Answer: True

# %% [markdown]
# # Q8. What algorithm for calculating Lyapunov exponents from data is schematized here?

# %%
Image('content_wolfschem.png')

# %% [markdown]
# ## Kantz's algorithm
# ## Wolf's algorithm
# ## Takens's algorithm
# ## Answer: Wolf's algorithm

# %% [markdown]
# # Q9. Wolf's algorithm for calculating Lyapunov exponents requires that you know the system equations.
# ## Answer: False

# %% [markdown]
# # Q10. You can calculate Lyapunov exponents directly from scalar data from a dynamical system using Kantz's algorithm, without any other preprocessing steps.
# ## Answer: False

# %% [markdown]
# # Q11. This question and the two that follow concern the difference between Wolf's algorithm for calculating Lyapunov exponents and Kantz's algorithm for calculating Lyapunov exponents.   Please mark each assertion as true or false.
# # Wolf's algorithm follows a number of trajectory points over time and uses their paths to determine how the dynamical system stretches the state space, whereas Kantz's algorithm just follows pairs of trajectory points to accomplish the same purpose.
#
# ## Answer: False

# %% [markdown]
# # Q12. Kantz's algorithm works with equations whereas Wolf's algorithm works with data.
# ## Answr: False

# %% [markdown]
# # Q13. Wolf's algorithm gives you all n of the Lyapunov exponents of an n-dimensional dynamical system, whereas Kantz's algorithm only gives you the largest one.
# ## Answer: False.

# %% [markdown]
# # Q14. Consider the following plot of the stretching factor produced by Kantz's algorithm on an experimental time series. Real-world effects (noise, etc.) make this plot less clean than the ones that you have seen in the videos and quizzes.

# %%
Image('content_actuallyap.jpg')

# %% [markdown]
# # What is the Lyapunov exponent of this trajectory?
# ##  Roughly 1.7646
# ## Roughly -1.7646
# ## Roughly -4.8858
# ## Roughly -1.4
# ## Roughly 0.25
# ## Roughly 2.25
# ## Answer: Roughly 1.7646

# %% [markdown]
# # Q15. Consider the following plot of the stretching factor produced by Kantz's algorithm on a different experimental time series.

# %%
Image('content_badlyap.jpg')

# %% [markdown]
# # What is the Lyapunov exponent of this trajectory?
# ## Roughly 0.02
# ## Roughly -0.02
# ## Roughly 0.07
# ## Roughly 0.1
# ## Roughly 0.4
# ## Roughly 3.0
# ## Undefined; there's no scaling region in this plot.
# ## Answer: Undefined; there's no scaling region in this plot.

# %% [markdown]
# # Q16. It's just as easy, from the standpoint of algorithmic complexity and data requirements, to calculate $\lambda_2$ from data as it is to calculate $\lambda_1$.
# ## Answer: False

# %% [markdown]
# # Q17. Low-pass filters remove all the low-frequency components of a scalar time-series data set.
# ## Answer: False

# %% [markdown]
# # Q18. The Farmer/Sidorowich filtering strategy leverages the attractor topology to remove noise.
# ## Answer: False

# %% [markdown]
# # Q19. Chaos and noise are easy to tell apart.
# ## Answer: False

# %% [markdown]
# # Q20. This is a schematic of a strategy that leverages the stable and unstable manifold structure of an attractor to remove noise from a measured trajectory.

# %%
Image('content_farmer-figs001.jpg')

# %% [markdown]
# # Answer: True.

# %% [markdown]
# # Q21. Which of these properties can be exploited to effectively remove noise from a chaotic signal?

# %% [markdown]
# ## A. The attractor topology.
# ## B. The stable and unstable manifolds.
# ## C. The frequency spectrum.
# ## All of A-C above.
# ## None of A-C above.
# ## A & B above.
# ## A & C above.
# ## B & C above.
# ## Answer: A & B above.
